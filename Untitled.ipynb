# %%
import pandas as pd

# %%
stock=''

# %%
df = pd.read_csv(stock+'.csv');

# %%
df
# Out:
#       Unnamed: 0           t           c           o           h           l  \
# 0              0  1347202799   46.052427   46.052427   46.052427   42.894547
# 1              1  1347289199   50.526092   46.052427   50.526092   46.841898
# 2              2  1347375599   55.526070   50.526092   55.526070   51.315562
# 3              3  1347461999   61.052361   55.526070   61.052361   56.578697
# 4              4  1347548399   67.104966   61.052361   67.104966   62.104988
# ...          ...         ...         ...         ...         ...         ...
# 1992        1992  1683471580  183.000000  187.000000  187.000000  183.000000
# 1993        1993  1683557980  181.500000  186.000000  186.000000  180.200000
# 1994        1994  1683644380  183.200000  184.900000  184.900000  180.400000
# 1995        1995  1683730780  183.200000  185.000000  185.000000  182.200000
# 1996        1996  1683817180  182.300000  185.000000  185.000000  182.000000
#
#           v   s
# 0        50  ok
# ...

# %%
df = df.drop('Unnamed: 0',axis=1)
df = df.drop('s',axis=1)

# %%
df['t'] = pd.to_datetime(df['t'], unit='s')

# %%
df.to_csv(stock+'final.csv')
