# %%
import pandas as pd

# %%
stock='ntc'

# %%
df = pd.read_csv('./Data/NTC.csv');

# %%
df
# Out:
#       Unnamed: 0           t            c            o            h  \
# 0              0  1325429999   355.833333   351.666667   358.333333
# 1              1  1325516399   363.333333   355.833333   363.333333
# 2              2  1325602799   362.500000   363.333333   362.500000
# 3              3  1325689199   354.166667   362.500000   364.166667
# 4              4  1325775599   362.500000   354.166667   362.500000
# ...          ...         ...          ...          ...          ...
# 2303        2303  1647788399  1291.666667  1307.500000  1312.500000
# 2304        2304  1647874799  1253.333333  1288.333333  1295.833333
# 2305        2305  1647961199  1273.333333  1241.666667  1275.000000
# 2306        2306  1648047599  1256.666667  1276.666667  1276.666667
# 2307        2307  1648133999  1220.833333  1259.166667  1262.416667
#
#                 l         v   s
# 0      354.166667     540.0  ok
# 1      350.000000    1266.0  ok
# 2      358.333333    1524.0  ok
# 3      354.166667    2424.0  ok
# 4      350.000000    1248.0  ok
# ...           ...       ...  ..
# 2303  1282.583333   68192.4  ok
# 2304  1241.666667  167144.4  ok
# 2305  1241.666667   85519.2  ok
# 2306  1241.666667   60688.8  ok
# 2307  1220.000000  190258.8  ok
#
# [2308 rows x 8 columns]

# %%
df = df.drop('Unnamed: 0',axis=1)
df = df.drop('s',axis=1)

# %%
df['t'] = pd.to_datetime(df['t'], unit='s')

# %%
df.to_csv(stock+'final.csv')
